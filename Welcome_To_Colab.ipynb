# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedalmokhtaradu-png/first-python-project-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
normal_lines = (input('write the normal line please. '))
print(normal_lines.replace('ass' , 'gyatt!') )
# Out:
# write the normal line please. ass
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1848/1920237369.py in <cell line: 0>()
# ----> 1 normal_lines = int((input('write the normal line please. ')))
#       2 print(normal_lines.replace('ass' , 'gyatt!'))
#
# ValueError: invalid literal for int() with base 10: 'ass'
