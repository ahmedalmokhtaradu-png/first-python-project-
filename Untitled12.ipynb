# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedalmokhtaradu-png/first-python-project-/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("your name,wtype it here.")
age = int(input("type your age in numbers please."))
ticket_type = input("what pose of a ticket do you have?")
if age >= 18:
    print(f"congrats {name} enjoy your movie")
elif age >= 18 and ticket_type == "vip":
    print(f"please {name} enjoy the vip special serves.")
else:
    print("sorry check your age again")
# Out:
# your name,wtype it here.oliver
# type your age in numbers please.17
# what pose of a ticket do you have?eco
# sorry check your age again

# %%
name = input("your name,wtype it here.")
age = int(input("type your age in numbers please."))
if age < 18:
  print("sorry your this movie is an r rated one")
# add a space or a tap to which is related tp which.
elif age >= 18 :

 ticket_type = input("what pose of a ticket do you have?")

 if ticket_type == "vip":
    print(f"please {name} enjoy the vip special serves.")
 else:
      print(f"congrats {name} enjoy your movie")
# Out:
# your name,wtype it here.moke
# type your age in numbers please.19
# what pose of a ticket do you have?vip
# please moke enjoy the vip special serves.

# %%
password = input("write a strong password.")
password_lengh = len(password)
if password_lengh >= 9 :
    print("wow")
else:
    print("tas weak")
# Out:
# write a strong password.6r84ghu8e7e48
# wow

# %%
name = input("enter the name of fatso")
waist_lengh = int(input("enter the mf's waist lengh"))
hight = int(input("write your hight"))
if waist_lengh >= hight // 4 :
    print("get in shape humen!!")
else:
    print("fat eating bactiria would starve on your body")
# Out:
# enter the name of fatsoABDULLAH
# enter the mf's waist lengh43
# write your hight179
# fat eating bactiria would starve on your body
