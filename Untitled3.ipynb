# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedalmokhtaradu-png/first-python-project-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price1 = 3000
price2 = 1500
choice = "price1" # Added definition for 'choice'
if choice == "price1":
  print("take this copoun with you!")
elif choice == "price2": # Corrected indentation for 'elif'
  print("make sure to tip!")
# Out:
# take this copoun with you!

# %%
value1 = "3"
value2 = "4"
dialed_num = '1+2'
if dialed_num =='1+2':
    print(value1)
elif dialed_num == '2+2':
   print(value2)
# Out:
# 3

# %%
score = 30
score = score + 20
print(score)
# Out:
# 50

# %%
grade1 = 84
grade2 = 90
selected_grade = grade1
if selected_grade >= 90 :
    print("amazing!!!")
elif selected_grade >= 80 :
    print("keep it up")
# Out:
# keep it up

# %%
final_grade3 = 90
additional_points3 = 5
score = final_grade3 + additional_points3
if score >= 90 :
    print("good chance")
elif score >= 100 :
    print("axepted") #i thoght i might ask about a key world that makes exaptions cause i couldve written that if the score is higher then 95 he can ask for an oppertonty to get additional points
# Out:
# good chance
