# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedalmokhtaradu-png/first-python-project-/blob/main/Overview_of_Colaboratory_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
num1 = 10
print(num1+a)
# Out:
# 20

# %%
name = "Adam"
greating_one = "hi"
greating_two = "hola"

print = (greating_one+name)

# %% [markdown]
# i made amistake earlier being using - as a separation tool instead of its set use being mathmatical

# %%
score = 10
score = score-9 #i'm trying to learn how "math like" coding is I am essuming the coulasion of "value" is prevented by what code id written first

print(score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/4280549870.py in <cell line: 0>()
#       2 score = score-9 #i'm trying to learn how "math like" coding is I am essuming the coulasion of "value" is prevented by what code id written first
#       3
# ----> 4 print(score)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# i'm thinking and iam coming with the idea is i might need a key word for the comp to identfy the problem
# *being a diffrent kind*
